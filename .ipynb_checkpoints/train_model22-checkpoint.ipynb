# %% [markdown]
# # Train a CNN model for end-to-end learning

# %%
# load libraries
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

import cv2
import matplotlib.image as mpimg

# %% [markdown]
# # 1. Data wrangling

# %% [markdown]
# ## 1.1 Read log file

# %%
# read data log
file_path = "/Users/daruizhang/Documents/Data/driving_log.csv"

#drive_log = pd.read_csv(file_path,header=None)
drive_log = pd.read_csv(file_path)

# peek the content
drive_log.head()

print(drive_log.shape)
# Out:
# (8036, 7)

# %% [markdown]
# ## 1.2 Get steering angle (Y)

# %%
# select the steering angle
Y = drive_log['steering']

# peek the data
print(Y.describe())

Y = np.asarray(Y)

# plot steering angle
plt.figure(figsize=(6, 2))

plt.plot(Y)
plt.ylabel('steering angle')
# Out:
# count    8036.000000
# mean        0.004070
# std         0.128840
# min        -0.942695
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: steering, dtype: float64

# %%
print(Y.std())
# Out:
# 0.128832055818

# %% [markdown]
# ## 1.3 Get image directory

# %%
# image directory
img_dir = drive_log['center']

# peek the directory
img_dir.head()
# Out:
# 0    IMG/center_2016_12_01_13_30_48_287.jpg
# 1    IMG/center_2016_12_01_13_30_48_404.jpg
# 2    IMG/center_2016_12_01_13_31_12_937.jpg
# 3    IMG/center_2016_12_01_13_31_13_037.jpg
# 4    IMG/center_2016_12_01_13_31_13_177.jpg
# Name: center, dtype: object

# %% [markdown]
# ## 1.4 Get image data

# %%
# load a image file given an image directory
def load_img(img_dir):
    img_dir = '/Users/daruizhang/Documents/Data/'+ img_dir
    img = mpimg.imread(img_dir)
    return img

# %%
# Test the function
img1 = load_img(img_dir[3000])

plt.imshow(img1) # plot image
print(img_dir[1])
print(img1.shape)
print(type(img1))
# Out:
# IMG/center_2016_12_01_13_30_48_404.jpg
# (160, 320, 3)
# <class 'numpy.ndarray'>

# %% [markdown]
# # 1.5 Preprocess image (grayscale, resize)

# %%
global img_x 
global img_y
img_x = 120 
img_y = 30

# %%
def process_img(img):
    # convert to grayscale    
    #img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # select area of interst
    img = img[60:140, 0:320]
    #print(img.shape)
    
    # reduce size
    #img = cv2.resize(img, (160, 40))
    img = cv2.resize(img, (img_x, img_y))
    
    # debug
    #print(img.shape)
    #plt.imshow(img)

    # add one more dimension
    #img  = np.reshape(img,[40, 160,1]) 
    #img  = np.reshape(img,[img_y, img_x,1]) 

    return img

# %%
# Test the function
img2 = process_img(img1)
print(img2.shape)
plt.imshow(img2)
# Out:
# (30, 120, 3)

# %% [markdown]
# # 1.6 Stack all images (X)

# %% [markdown]
# ### Inicialize

# %%
# inicialize X
#X = np.empty((n_img,40,160,1))
n_img = len(img_dir)
X = np.empty((n_img,img_y,img_x,3))

print(X.shape)
# Out:
# (8036, 30, 120, 3)

# %%
# stack the image to make X
def stack_img(img_dir): # input directory, and image
    n_img = len(img_dir)
    for n in range(n_img):
        img = load_img(img_dir[n]) # load color image
        img = process_img(img) # grey and small
        X[n,:,:,:]=img
    return X

# %%
X = stack_img(img_dir)
print(X.shape)
# Out:
# (8036, 30, 120, 3)

# %%
# Test if the funciton is corect
img = X[3000,:,:,:]
print(img.shape)
#img  = np.reshape(img,[16, 32]) # reshape
#img  = np.reshape(img,[40, 160]) # reshape
#img  = np.reshape(img,[img_y, img_x]) # reshape


print(img.shape)
plt.imshow(img)# show image
# Out:
# (30, 120, 3)
# (30, 120, 3)

# %%
print(Y)
# Out:
# [ 0.  0.  0. ...,  0.  0.  0.]

# %%
plt.plot(Y)
plt.ylabel('steering angle')

# %% [markdown]
# # save X and Y

# %%
#Binary data
#np.save('X.npy', X)
#np.save('Y.npy', Y)

# %% [markdown]
# # 2. CNN model

# %%
# load library
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, MaxPooling2D
from keras.optimizers import SGD, Adam, RMSprop
# Out:
# Using TensorFlow backend.

# %%
# input shape
input_shape = X.shape[1:]
print(input_shape, 'input shape')
# Out:
# (30, 120, 3) input shape

# %%
from sklearn.cross_validation import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2)

print('Train size:', X_train.shape)
print('Test size:', X_test.shape)
# Out:
# Train size: (6428, 30, 120, 3)
# Test size: (1608, 30, 120, 3)

# %% [markdown]
# ## 2.1 define CNN

# %%
# Initiating the model

model = Sequential()

model.add(Convolution2D(24, 4, 4,input_shape = input_shape, name='cn1'))
#model.add(Dropout(0.4))
model.add(Activation('relu'))

#model.add(Convolution2D(8, 4, 4,name='cn2'))
#model.add(Dropout(0.4))
#model.add(Activation('relu'))


model.add(Flatten(name='flatten'))

model.add(Dense(10, name='fc1'))
#model.add(Dropout(0.4))
model.add(Activation('relu'))


model.add(Dense(1, name='fc3'))


# Print out summary of the model
model.summary()

# Compile model using Adam optimizer 
model.compile(loss='mean_squared_error',
              optimizer=Adam())
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# cn1 (Convolution2D)              (None, 27, 117, 24)   1176        convolution2d_input_3[0][0]
# ____________________________________________________________________________________________________
# activation_7 (Activation)        (None, 27, 117, 24)   0           cn1[0][0]
# ____________________________________________________________________________________________________
# flatten (Flatten)                (None, 75816)         0           activation_7[0][0]
# ____________________________________________________________________________________________________
# fc1 (Dense)                      (None, 10)            758170      flatten[0][0]
# ____________________________________________________________________________________________________
# activation_8 (Activation)        (None, 10)            0           fc1[0][0]
# ____________________________________________________________________________________________________
# fc3 (Dense)                      (None, 1)             11          activation_8[0][0]
# ====================================================================================================
# Total params: 759357
# ____________________________________________________________________________________________________

# %% [markdown]
# ## 2.2 Train model

# %%
history = model.fit(X_train, y_train, 
                    batch_size = 64, nb_epoch= 5, 
                    verbose=1, callbacks=[], validation_split=0.3, 
                    validation_data=None, shuffle=True, 
                    class_weight=None, sample_weight=None)
# Out:
# Train on 4499 samples, validate on 1929 samples
# Epoch 1/5
# 4499/4499 [==============================] - 55s - loss: 185.5078 - val_loss: 0.0163
# Epoch 2/5
# 4499/4499 [==============================] - 56s - loss: 0.0169 - val_loss: 0.0163
# Epoch 3/5
# 4499/4499 [==============================] - 59s - loss: 0.0169 - val_loss: 0.0163
# Epoch 4/5
# 4499/4499 [==============================] - 52s - loss: 0.0173 - val_loss: 0.0163
# Epoch 5/5
# 4499/4499 [==============================] - 53s - loss: 0.0169 - val_loss: 0.0163

# %%
history = model.fit(X_train, y_train, 
                    batch_size = 64, nb_epoch= 3, 
                    verbose=1, callbacks=[], validation_split=0.3,shuffle=True)
# Out:
# Train on 4499 samples, validate on 1929 samples
# Epoch 1/3
# 4499/4499 [==============================] - 21s - loss: 3604.5674 - val_loss: 0.3300
# Epoch 2/3
# 4499/4499 [==============================] - 16s - loss: 0.2876 - val_loss: 0.1374
# Epoch 3/3
# 4499/4499 [==============================] - 15s - loss: 0.1271 - val_loss: 0.0753

# %% [markdown]
# # 2.3 Test model performance

# %% [markdown]
# ## Test on the test set

# %%
# test statis
print("Test on the test set:")
print('std:', y_test.std())
print('mean:', y_test.mean())

# test results 
pred_test = model.predict(
                    x = X_test,
                    batch_size=1,
                    verbose=1)

# plot test set
plt.figure(1)  
plt.figure(figsize=(6, 2))
plt.title('prediction')
plt.plot(pred_test)

plt.figure(2)  
plt.figure(figsize=(6, 2))
plt.title('test data')
plt.plot(np.asarray(y_test))


print('pred_test:',pred_test)
# Out:
# Test on the test set:
# std: 0.122100943644
# mean: -0.000151003187811
# 1606/1608 [============================>.] - ETA: 0spred_test: [[-0.00026689]
#  [ 0.0086738 ]
#  [-0.00026689]
#  ...,
#  [-0.00026689]
#  [-0.00026689]
#  [-0.00026689]]

# %% [markdown]
# ## Test on the traing set

# %%
# training statistic
print("Test on the training set:")
print("std:",y_train.std())
print("mean:",y_train.mean())


# trainging results
pred_train = model.predict(
                    x = X_train,
                    batch_size=1,
                    verbose=1)

# plot test set
plt.figure(1)  
plt.figure(figsize=(6, 2))
plt.title('prediction')
plt.plot(pred_train)

plt.figure(2)  
plt.figure(figsize=(6, 2))
plt.title('test data')
plt.plot(np.asarray(y_train))



print('pred_train:',pred_train)
# Out:
# Test on the training set:
# std: 0.130440235067
# mean: 0.00512546248149
# 6427/6428 [============================>.] - ETA: 0spred_train: [[ -2.66894407e-04]
#  [  1.28059119e-01]
#  [ -2.66894407e-04]
#  ...,
#  [ -9.96204913e-01]
#  [ -2.66894407e-04]
#  [ -2.66894407e-04]]

# %% [markdown]
# # 2.3 Save weights and model

# %%
# load library
import json
import h5py

# %%
# Save model as json file
json_string = model.to_json()

# save weights
with open('model.json', 'w') as outfile:
        json.dump(json_string, outfile)

        # save weights
        model.save_weights('./model.h5')
        print("Model saved")
# Out:
# Model saved
